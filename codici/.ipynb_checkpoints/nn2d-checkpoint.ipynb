# %%
from IPython.display import Image
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import scipy.special as sp
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.regularizers import L1L2
from keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn.apionly as sns

plt.style.use('fivethirtyeight')

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.serif'] = 'Ubuntu'
plt.rcParams['font.monospace'] = 'Ubuntu Mono'
plt.rcParams['font.size'] = 10
plt.rcParams['axes.labelsize'] = 10
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 10
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.titlesize'] = 12
plt.rcParams['image.cmap'] = 'jet'
plt.rcParams['image.interpolation'] = 'none'
plt.rcParams['figure.figsize'] = (16, 8)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.markersize'] = 8

colors = ['#008fd5', '#fc4f30', '#e5ae38', '#6d904f', '#8b8b8b', '#810f7c', 
'#137e6d', '#be0119', '#3b638c', '#af6f09', '#008fd5', '#fc4f30', '#e5ae38', '#6d904f', '#8b8b8b', 
'#810f7c', '#137e6d', '#be0119', '#3b638c', '#af6f09']

cmap = mcolors.LinearSegmentedColormap.from_list("", ["#82cafc", "#069af3", "#0485d1", colors[0], colors[8]])

# %%
class my_cb(Callback):
    def __init__(self):
        self.epoch = 0
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        print('.',end='')
        
    def on_epoch_end(self, batch, logs={}):
        self.epoch += 1
        print('\n')
        print("{0:3d} epochs: accuracy={1:5.4f}".format(self.epoch, logs['accuracy']))

# %%
# legge i dati in dataframe pandas
data = pd.read_csv("ex2data1.txt", header=0, delimiter=',', names=['x1','x2','t'])
# calcola dimensione dei dati
n = len(data)

# calcola dimensionalità delle features
nfeatures = len(data.columns)-1

X = np.array(data[['x1','x2']])
t = np.array(data['t']).reshape(-1,1)

data[['x1','x2']] = StandardScaler().fit_transform(X)

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.gca()
ax.scatter(data[data.t==0].x1, data[data.t==0].x2, s=40, color=colors[0], edgecolor='k', alpha=.7)
ax.scatter(data[data.t==1].x1, data[data.t==1].x2, s=40, color=colors[1], edgecolor='k', alpha=.7)
plt.xlabel('$x_1$', fontsize=12)
plt.ylabel('$x_2$', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('Dataset', fontsize=12)
plt.show()

# %%
num_classes = np.unique(t).shape[0]

# %%
t1 = to_categorical(t, num_classes)

# %%
delta1=max(data.x1)-min(data.x1)
delta2=max(data.x2)-min(data.x2)
min1=min(data.x1)-delta1/10
max1=max(data.x1)+delta1/10
min2=min(data.x2)-delta2/10
max2=max(data.x2)+delta2/10
u = np.linspace(min1, max1, 100)
v = np.linspace(min2, max2, 100)
u, v = np.meshgrid(u, v)

# %%
model0 = Sequential([
    Dense(15, input_dim=2, activation='relu'),
    Dense(64, activation='relu'),
#    Dense(32, activation='relu'),
#    Dense(32, activation='relu'),
#    Dense(32, activation='relu'),
#    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])

model0.compile(optimizer=Adam(lr=0.01), loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model0.summary()
# Out:
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_60 (Dense)             (None, 15)                45
# _________________________________________________________________
# dense_61 (Dense)             (None, 64)                1024
# _________________________________________________________________
# dense_62 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 1,134
# Trainable params: 1,134
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 10
epochs = 30

history = model0.fit(X_s, t.ravel(), shuffle=True, batch_size=5, epochs=epochs, verbose=1, callbacks=[my_cb()])
# Out:
# Epoch 1/30
# 99/99 [==============================] - 0s 510us/step - loss: 0.0927 - accuracy: 0.9798............
#
#
#   1 epochs: accuracy=0.9798
# Epoch 2/30
# 99/99 [==============================] - 0s 347us/step - loss: 0.1485 - accuracy: 0.9293................
#
#
#   2 epochs: accuracy=0.9293
# Epoch 3/30
# 99/99 [==============================] - 0s 293us/step - loss: 0.1001 - accuracy: 0.9697................
#
#
#   3 epochs: accuracy=0.9697
# Epoch 4/30
# 99/99 [==============================] - 0s 321us/step - loss: 0.0542 - accuracy: 0.9798............
#
#
#   4 epochs: accuracy=0.9798
# Epoch 5/30
# 99/99 [==============================] - 0s 260us/step - loss: 0.0650 - accuracy: 0.9798............
#
#
#   5 epochs: accuracy=0.9798
# Epoch 6/30
# 99/99 [==============================] - 0s 341us/step - loss: 0.0807 - accuracy: 0.9596................
#
#
#   6 epochs: accuracy=0.9596
# Epoch 7/30
# 99/99 [==============================] - 0s 304us/step - loss: 0.0851 - accuracy: 0.9697............
#
#
#   7 epochs: accuracy=0.9697
# Epoch 8/30
# 99/99 [==============================] - 0s 385us/step - loss: 0.0556 - accuracy: 0.9798............
#
#
#   8 epochs: accuracy=0.9798
# Epoch 9/30
# 99/99 [==============================] - 0s 387us/step - loss: 0.0596 - accuracy: 0.9798............
#
#
#   9 epochs: accuracy=0.9798
# Epoch 10/30
# 99/99 [==============================] - 0s 365us/step - loss: 0.0673 - accuracy: 0.9596............
#
#
#  10 epochs: accuracy=0.9596
# Epoch 11/30
# 99/99 [==============================] - 0s 369us/step - loss: 0.0443 - accuracy: 0.9899............
#
#
#  11 epochs: accuracy=0.9899
# Epoch 12/30
# 99/99 [==============================] - 0s 574us/step - loss: 0.0559 - accuracy: 0.9798..........
#
#
#  12 epochs: accuracy=0.9798
# Epoch 13/30
# 99/99 [==============================] - 0s 507us/step - loss: 0.0856 - accuracy: 0.9798............
#
#
#  13 epochs: accuracy=0.9798
# Epoch 14/30
# 99/99 [==============================] - 0s 453us/step - loss: 0.0346 - accuracy: 0.9899............
#
#
#  14 epochs: accuracy=0.9899
# Epoch 15/30
# 99/99 [==============================] - 0s 334us/step - loss: 0.0831 - accuracy: 0.9596................
#
#
#  15 epochs: accuracy=0.9596
# Epoch 16/30
# 99/99 [==============================] - 0s 547us/step - loss: 0.0899 - accuracy: 0.9596............
#
#
#  16 epochs: accuracy=0.9596
# Epoch 17/30
# 99/99 [==============================] - 0s 431us/step - loss: 0.1102 - accuracy: 0.9899............
#
#
#  17 epochs: accuracy=0.9899
# Epoch 18/30
# 99/99 [==============================] - 0s 369us/step - loss: 0.0492 - accuracy: 0.9697................
#
#
#  18 epochs: accuracy=0.9697
# Epoch 19/30
# 99/99 [==============================] - 0s 333us/step - loss: 0.0387 - accuracy: 0.9899............
#
#
#  19 epochs: accuracy=0.9899
# Epoch 20/30
# 99/99 [==============================] - 0s 374us/step - loss: 0.0372 - accuracy: 0.9798............
#
#
#  20 epochs: accuracy=0.9798
# Epoch 21/30
# 99/99 [==============================] - 0s 310us/step - loss: 0.0738 - accuracy: 0.9596............
#
#
#  21 epochs: accuracy=0.9596
# Epoch 22/30
# 99/99 [==============================] - 0s 378us/step - loss: 0.0585 - accuracy: 0.9899................
#
#
#  22 epochs: accuracy=0.9899
# Epoch 23/30
# 99/99 [==============================] - 0s 350us/step - loss: 0.2853 - accuracy: 0.9293............
#
#
#  23 epochs: accuracy=0.9293
# Epoch 24/30
# 99/99 [==============================] - 0s 388us/step - loss: 0.1006 - accuracy: 0.9798............
#
#
#  24 epochs: accuracy=0.9798
# Epoch 25/30
# 99/99 [==============================] - 0s 292us/step - loss: 0.0432 - accuracy: 0.9899............
#
#
#  25 epochs: accuracy=0.9899
# Epoch 26/30
# 99/99 [==============================] - 0s 439us/step - loss: 0.0404 - accuracy: 0.9798............
#
#
#  26 epochs: accuracy=0.9798
# Epoch 27/30
# 99/99 [==============================] - 0s 389us/step - loss: 0.0576 - accuracy: 0.9798............
#
#
#  27 epochs: accuracy=0.9798
# Epoch 28/30
# 99/99 [==============================] - 0s 402us/step - loss: 0.0358 - accuracy: 0.9798............
#
#
#  28 epochs: accuracy=0.9798
# Epoch 29/30
# 99/99 [==============================] - 0s 303us/step - loss: 0.0297 - accuracy: 0.9899............
#
#
#  29 epochs: accuracy=0.9899
# Epoch 30/30
# 99/99 [==============================] - 0s 300us/step - loss: 0.0392 - accuracy: 0.9899............
#
#
#  30 epochs: accuracy=0.9899

# %%
pd.DataFrame(history.history)
# Out:
#         loss    accuracy
# 0   0.092719  0.97979796
# 1   0.148519   0.9292929
# 2   0.100068    0.969697
# 3   0.054240  0.97979796
# 4   0.064976  0.97979796
# 5   0.080747    0.959596
# 6   0.085121    0.969697
# 7   0.055592  0.97979796
# 8   0.059632  0.97979796
# 9   0.067343    0.959596
# 10  0.044308    0.989899
# 11  0.055910  0.97979796
# 12  0.085633  0.97979796
# 13  0.034578    0.989899
# 14  0.083116    0.959596
# 15  0.089859    0.959596
# 16  0.110205    0.989899
# 17  0.049238    0.969697
# 18  0.038654    0.989899
# 19  0.037152  0.97979796
# 20  0.073798    0.959596
# 21  0.058498    0.989899
# 22  0.285307   0.9292929
# 23  0.100633  0.97979796
# 24  0.043218    0.989899
# 25  0.040381  0.97979796
# 26  0.057632  0.97979796
# 27  0.035819  0.97979796
# 28  0.029684    0.989899
# 29  0.039227    0.989899

# %%
z = model0.predict(np.c_[u.ravel(), v.ravel()])

# %%
z = z[:,0].reshape(u.shape)

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.gca()
imshow_handle = plt.imshow(z, origin='lower', aspect='auto', extent=(min1, max1, min2, max2), alpha=.3)
ax.scatter(data[data.t==0].x1, data[data.t==0].x2, edgecolor='k', s=40, color=colors[0], alpha=.7)
ax.scatter(data[data.t==1].x1, data[data.t==1].x2, edgecolor='k', s=40, color=colors[1], alpha=.7)
plt.contour(u, v, z, [0.5], colors=[colors[8]], linewidths=[1.5])
plt.xlabel('Punteggio esame 1', fontsize=10)
plt.ylabel('Punteggio esame 2', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
y = model0.predict(data[['x1','x2']])[:,0]

# %%
y = np.where(y>0.5, 1, 0)

# %%
cm = confusion_matrix(t,y)
cm
# Out:
# array([[39,  0],
#        [ 0, 60]])

# %%
pr = precision_recall_fscore_support(t,y)

# %%
print('Classe 0: precision={0:5.3f}, recall={1:5.3f}'.format(pr[0][0], pr[1][0]))

print('Classe 1: precision={0:5.3f}, recall={1:5.3f}'.format(pr[1][0], pr[1][1]))

print('Accuracy={0:5.3f}'.format(accuracy_score(t,y)))
# Out:
# Classe 0: precision=1.000, recall=1.000
# Classe 1: precision=1.000, recall=1.000
# Accuracy=1.000
